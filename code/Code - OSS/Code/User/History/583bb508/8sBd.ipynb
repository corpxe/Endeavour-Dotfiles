# %%
# Step 1: Import required libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random

# Step 2: Create sample data
x = np.linspace(0, 10, 100)   # 100 points from 0 to 10
y1 = x                        # Line 1
y2 = x**2                     # Line 2
y3 = x**3                     # Line 3

# Step 3: Create figure and subplot
fig, ax = plt.subplots()

# Step 4: Plot 3 different lines with styles and colors
ax.plot(x, y1, color='blue', linestyle='-', label='Linear (y = x)')
ax.plot(x, y2, color='red', linestyle='--', label='Quadratic (y = x^2)')
ax.plot(x, y3, color='green', linestyle='-.', label='Sine (y = x^3')

# Step 5: Add title and legend
ax.set_title("Sample Multi-Line Plot")
ax.legend()

# Step 6: Show the plot
plt.show()

# %%
dict = {"Keys" : ['A','B','C','D','E'],"Values" : [range(0,11,2),['A','B','C','D','E'],
                                                   [(i*100)//1 for i in [random.random() for _ in range(5)]],
                                                   [random.randint(10,21) for _ in range(5)]]}
df = pd.DataFrame(dict)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 dict = {"Keys" : ['A','B','C','D','E'],"Values" : [range(0,11,2),['A','B','C','D','E'],[(i*100)//1 for i in [random.random() for _ in range(5)]],[random.randint(10,21) for _ in range(5)]]}
# ----> 2 df = pd.DataFrame(dict)
#       3 df
#
# File ~/Desktop/Python/venv/lib/python3.14/site-packages/pandas/core/frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     765             )
#     766
#     767         elif isinstance(data, dict):
#     768             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770         elif isinstance(data, ma.MaskedArray):
#     771             from numpy.ma import mrecords
#     772
#
# File ~/Desktop/Python/venv/lib/python3.14/site-packages/pandas/core/internals/construction.py:460, in dict_to_mgr(data, index, columns, dtype, copy)
#     441 if copy:
#     442     # We only need to copy arrays that will not get consolidated, i.e.
#     443     #  only EA arrays
#     444     arrays = [
#     445         (
#     446             x.copy()
#    (...)    457         for x in arrays
#     458     ]
# --> 460 return arrays_to_mgr(arrays, columns, index, dtype=dtype, consolidate=copy)
#
# File ~/Desktop/Python/venv/lib/python3.14/site-packages/pandas/core/internals/construction.py:113, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, consolidate)
#     110 if verify_integrity:
#     111     # figure out the index, if necessary
#     112     if index is None:
# --> 113         index = _extract_index(arrays)
#     114     else:
#     115         index = ensure_index(index)
#
# File ~/Desktop/Python/venv/lib/python3.14/site-packages/pandas/core/internals/construction.py:643, in _extract_index(data)
#     641 if have_raw_arrays:
#     642     if len(raw_lengths) > 1:
# --> 643         raise ValueError("All arrays must be of the same length")
#     645     if have_dicts:
#     646         raise ValueError(
#     647             "Mixing dicts with non-Series may lead to ambiguous ordering."
#     648         )
#
# ValueError: All arrays must be of the same length

# %%
df = df.set_index('Keys')
df
# Out:
#                    Values
# Keys
# A     (0, 2, 4, 6, 8, 10)
# B         [A, B, C, D, E]
